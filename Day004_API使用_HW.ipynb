# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests, json

url = 'https://cat-fact.herokuapp.com'
fact = '/facts/random?animal_type=cat&amount=3'

r = requests.get(url+fact)
r.text
# Out:
# '[{"status":{"verified":null,"sentCount":0},"type":"cat","deleted":false,"_id":"5f65782b2da500001732b82a","used":false,"source":"user","user":"5f6577fa2da500001732b829","text":"Grateful.","createdAt":"2020-09-19T03:16:59.381Z","updatedAt":"2020-09-19T03:16:59.381Z","__v":0},{"status":{"verified":true,"sentCount":1},"type":"cat","deleted":false,"_id":"591f9894d369931519ce358f","__v":0,"text":"A female cat will be pregnant for approximately 9 weeks - between 62 and 65 days from conception to delivery.","source":"api","updatedAt":"2020-08-23T20:20:01.611Z","createdAt":"2018-01-04T01:10:54.673Z","used":false,"user":"5a9ac18c7478810ea6c06381"},{"status":{"verified":true,"sentCount":1},"type":"cat","deleted":false,"_id":"591f9854c5cbe314f7a7ad34","__v":0,"text":"It has been scientifically proven that stroking a cat can lower one\'s blood pressure.","source":"api","updatedAt":"2020-08-23T20:20:01.611Z","createdAt":"2018-01-04T01:10:54.673Z","used":false,"user":"5a9ac18c7478810ea6c06381"}]'

# %%
json.loads(r.text)
# Out:
# [{'status': {'verified': None, 'sentCount': 0},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '5f65782b2da500001732b82a',
#   'used': False,
#   'source': 'user',
#   'user': '5f6577fa2da500001732b829',
#   'text': 'Grateful.',
#   'createdAt': '2020-09-19T03:16:59.381Z',
#   'updatedAt': '2020-09-19T03:16:59.381Z',
#   '__v': 0},
#  {'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '591f9894d369931519ce358f',
#   '__v': 0,
#   'text': 'A female cat will be pregnant for approximately 9 weeks - between 62 and 65 days from conception to delivery.',
#   'source': 'api',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'createdAt': '2018-01-04T01:10:54.673Z',
#   'used': False,
#   'user': '5a9ac18c7478810ea6c06381'},
#  {'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '591f9854c5cbe314f7a7ad34',
#   '__v': 0,
#   'text': "It has been scientifically proven that stroking a cat can lower one's blood pressure.",
#   'source': 'api',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'createdAt': '2018-01-04T01:10:54.673Z',
#   'used': False,
#   'user': '5a9ac18c7478810ea6c06381'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
url = 'https://cat-fact.herokuapp.com'
fact = '/facts/5fcf06b0d5cf0e00174aa064'

r = requests.get(url+fact)
json.loads(r.text)
# Out:
# {'status': {'verified': None, 'sentCount': 0},
#  'type': 'cat',
#  'deleted': False,
#  '_id': '5fcf06b0d5cf0e00174aa064',
#  'used': False,
#  'source': 'user',
#  'user': {'name': {'first': 'Artur', 'last': 'Linnik'},
#   'photo': 'https://lh3.googleusercontent.com/a-/AOh14Gji-pOt2MqTGwuvEvHKtzVOYvgxdIA0QhvcKueKKg=s50',
#   '_id': '5fcf06a5d5cf0e00174aa063'},
#  'text': 'Test too.',
#  'createdAt': '2020-12-08T04:53:04.606Z',
#  'updatedAt': '2020-12-08T04:53:04.606Z',
#  '__v': 0}

# %%
url = 'https://cat-fact.herokuapp.com'
fact = '/facts?animal_type=cat,horse'

r = requests.get(url+fact)
json.loads(r.text)
# Out:
# [{'status': {'verified': True, 'sentCount': 1, 'feedback': ''},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '5887e1d85c873e0011036889',
#   'user': '5a9ac18c7478810ea6c06381',
#   'text': 'Cats make about 100 different sounds. Dogs make only about 10.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-09-03T16:39:39.578Z',
#   'createdAt': '2018-01-15T21:20:00.003Z',
#   'used': True},
#  {'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '588e746706ac2b00110e59ff',
#   'user': '588e6e8806ac2b00110e59c3',
#   'text': 'Domestic cats spend about 70 percent of the day sleeping and 15 percent of the day grooming.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-26T20:20:02.359Z',
#   'createdAt': '2018-01-14T21:20:02.750Z',
#   'used': True},
#  {'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '58923f2fc3878c0011784c79',
#   'user': '5887e9f65c873e001103688d',
#   'text': "I don't know anything about cats.",
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'createdAt': '2018-02-25T21:20:03.060Z',
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '5894af975cdc7400113ef7f9',
#   'user': '5a9ac18c7478810ea6c06381',
#   'text': 'The technical term for a cat’s hairball is a bezoar.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-11-25T21:20:03.895Z',
#   'createdAt': '2018-02-27T21:20:02.854Z',
#   'used': True},
#  {'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '58e007cc0aac31001185ecf5',
#   'user': '58e007480aac31001185ecef',
#   'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'createdAt': '2018-03-01T21:20:02.713Z',
#   'used': False}]

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36',
    'Referer': 'https://shopee.tw/shop/1819984/search?shopCollection=9271157',
    'X-Requested-With': 'XMLHttpRequest',
}   

url = 'https://shopee.tw/api/v2/search_items/?by=pop&limit=30&match_id=1819984&newest=0&order=desc&page_type=shop&shop_categoryids=9271157&version=2'

r = requests.get(url,headers=headers)
json.loads(r.text)
# Out:
# {'show_disclaimer': False,
#  'query_rewrite': {},
#  'adjust': {},
#  'version': '86d13d64ce4f334de11c5a4a9d4036b0',
#  'algorithm': 'eyJzZWFyY2giOiI3LmEuMjMwQEhVVldYMExNMSIsImFkcyI6Im9nWUEifQ==',
#  'need_next_search': True,
#  'total_count': 44,
#  'error': None,
#  'total_ads_count': 0,
#  'disclaimer_infos': [],
#  'nomore': False,
#  'price_adjust': {},
#  'json_data': '',
#  'suggestion_algorithm': 0,
#  'items': [{'itemid': 1232970679,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': 'b4156657ae0a0cbf5c5aeec9e1e0dc4d',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': True,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['b4156657ae0a0cbf5c5aeec9e1e0dc4d',
#     'ef36131af35bd6a3db67db4160ac8496',
#     'efda5f2bfe59d4460a4cf54ff68c1bb7'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 12,
#    'view_count': 27,
#    'display_name': None,
#    'catid': 76,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'dm',
#    'price_min': 30000000,
#    'liked_count': 8,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 224,
#    'status': 1,
#    'price_max': 30000000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 30000000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [12, 0, 0, 0, 0, 12],
#     'rcount_with_image': 0,
#     'rcount_with_context': 2},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '現貨+預購  Balea臉部保養安瓶(玻尿酸保濕/7日煥膚/活膚緊緻) 日常保養 新娘定妝 一盒7入',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1528504099,
#    'wholesale_tier_list': [{'min_count': 2, 'price': 28500000, 'max_count': 5},
#     {'min_count': 6, 'price': 27000000, 'max_count': 10},
#     {'min_count': 11, 'price': 26000000, 'max_count': 50},
#     {'min_count': 51, 'price': 24500000, 'max_count': None}],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [1000028],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 71,
#    'transparent_background_image': ''},
#   {'itemid': 2729764492,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': 'd07391ad9041f495756446a837335655',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['d07391ad9041f495756446a837335655',
#     '735f72e7e7bdbaec1845b654aba0fb14',
#     '40feb7f068d5d4f05a623df70f6b9f3c',
#     '20175683480e51cc1aad264f52d75ed4',
#     '46a9c34b61424d8f90c2f83b1963ce52',
#     'af04794732884a59b423a35b2e232fef',
#     '2189246adc56d4a257724e75c09a350e'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 14,
#    'view_count': 36,
#    'display_name': None,
#    'catid': 2580,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'invisibobble',
#    'price_min': 7500000,
#    'liked_count': 21,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 11,
#    'status': 1,
#    'price_max': 21000000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 7500000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [14, 0, 0, 0, 0, 14],
#     'rcount_with_image': 3,
#     'rcount_with_context': 3},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': [],
#      'properties': [],
#      'type': 0,
#      'name': '流線魔髮圈',
#      'options': ['銀澤色3入',
#       '金澤光3入',
#       '古銅光3入',
#       '仙女光3入',
#       '透明單條',
#       '金澤單條',
#       '古銅單條',
#       '仙女單條',
#       '銀澤單條']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '💯現貨供應 💯德國 Invisibobble 神奇魔髮圈流線魔髮圈',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1567079715,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 27,
#    'transparent_background_image': ''},
#   {'itemid': 1202630620,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': 'a6969081b86d17a0a1c1628709c0e65d',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['a6969081b86d17a0a1c1628709c0e65d',
#     'cedf1177dec65147f51dc22ee637c2dd',
#     '153ea5dd75d98bbfc31578abcbd89e92'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 16,
#    'view_count': 49,
#    'display_name': None,
#    'catid': 67,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'Balea(芭樂雅)',
#    'price_min': 15500000,
#    'liked_count': 17,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 1,
#    'status': 1,
#    'price_max': 15500000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 15500000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 4.875,
#     'rating_count': [16, 0, 0, 1, 0, 15],
#     'rcount_with_image': 0,
#     'rcount_with_context': 6},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': [],
#      'properties': [],
#      'type': 0,
#      'name': '選項',
#      'options': ['洗前護理', '密集修復', '夜間修復']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '出清現貨✨✨✨德國 Balea 摩洛哥護髮油 洗前護理/密集修復/夜間修復 100ml售完不補👈👈👈',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1527585679,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 35,
#    'transparent_background_image': ''},
#   {'itemid': 2729686801,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': '4b8e8a1d8dc7ce29f1e4f2e0e33bc150',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['4b8e8a1d8dc7ce29f1e4f2e0e33bc150',
#     'e470eb7a6a4ecda18b494af535e00030',
#     'f34f6b461e902f3ee9c6be1e7fcc862d',
#     '8e0f0bf2da20f1344f8b7b524a296fc7',
#     '90e895cad6b3908b7d8ad5325f431fc6',
#     '702528e725df319584926ba093db40a5',
#     'c86d0f12c3fdb8028586ab2082bd4750',
#     'af6f15844a22034e9db00d37567ef282',
#     '4352b6489fe0dcab97ec6b5b73893b7c'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 11,
#    'view_count': 20,
#    'display_name': None,
#    'catid': 2580,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'invisibobble',
#    'price_min': 21500000,
#    'liked_count': 7,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 9,
#    'status': 1,
#    'price_max': 21500000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 21500000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [11, 0, 0, 0, 0, 11],
#     'rcount_with_image': 3,
#     'rcount_with_context': 3},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': [],
#      'properties': [],
#      'type': 0,
#      'name': '限量款',
#      'options': ['西瓜3入',
#       '鳳梨3入',
#       '哈密瓜3入',
#       '拆售 西瓜有吊飾',
#       '拆售 鳳梨有吊飾',
#       '拆售 哈密瓜有吊飾',
#       '西瓜6入',
#       '鳳梨6入',
#       '哈密瓜6入',
#       '✨闆媽甜甜經典混色3入']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '💯現貨供應 💯德國 Invisibobble 神奇魔髮圈 夏日水果限量款',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1567078848,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 16,
#    'transparent_background_image': ''},
#   {'itemid': 2729817555,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': 'f681d4753eb443d4a9d83b0777c16fa9',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['f681d4753eb443d4a9d83b0777c16fa9',
#     '222d10f7efb98cbed856a8fe5ad2a25e',
#     'f26fd07b5bd37f6257c8df106d622e4d',
#     'cc2de4e6b7e90147d449eebb9f33e09e',
#     '8efc5c6cbdce923af8e7d89a2a584976',
#     '65190784f9595139d2c509d58a0865ff',
#     '2189246adc56d4a257724e75c09a350e',
#     '00b1768e4f959a9877579a5d497e7abd'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 11,
#    'view_count': 27,
#    'display_name': None,
#    'catid': 2580,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'invisibobble',
#    'price_min': 7500000,
#    'liked_count': 16,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 70,
#    'status': 1,
#    'price_max': 20900000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 7500000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 4.909091,
#     'rating_count': [11, 0, 0, 0, 1, 10],
#     'rcount_with_image': 1,
#     'rcount_with_context': 2},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': [],
#      'properties': [],
#      'type': 0,
#      'name': '經典款',
#      'options': ['純黑3入',
#       '咖啡3入',
#       '霧粉3入',
#       '透明3入',
#       '咖啡單入',
#       '霧粉單入',
#       '純黑單入',
#       '透明單入']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '💯現貨供應 💯德國 Invisibobble 神奇魔髮圈 經典款',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1567080310,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 16,
#    'transparent_background_image': ''},
#   {'itemid': 1273171495,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': '46b1be80afb8a33bf2cce3e98fa9c8dd',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['46b1be80afb8a33bf2cce3e98fa9c8dd',
#     'ff6e669f6ef0d91bfe5e19ed069b7647',
#     '6ac9c7d3dcaa14384eb7c1cfd523f191',
#     '3be8d6932b228b7089d549fb1596833c',
#     'd87ee1fc244d23212d61a869e0295809'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 5,
#    'view_count': 1,
#    'display_name': None,
#    'catid': 76,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'Denkmit',
#    'price_min': 9900000,
#    'liked_count': 8,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 33,
#    'status': 1,
#    'price_max': 9900000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 9900000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [5, 0, 0, 0, 0, 5],
#     'rcount_with_image': 0,
#     'rcount_with_context': 1},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '現貨☆ 德國 Denkmit洗衣機強力清潔去汙抑菌消毒錠 10入特價中',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1530150743,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 16,
#    'transparent_background_image': ''},
#   {'itemid': 1204047807,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': 'b6417523f885c995f58e2bf1501e8738',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['b6417523f885c995f58e2bf1501e8738',
#     'a7e957cfeac00152b19308505b6d1a80'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 5,
#    'view_count': 4,
#    'display_name': None,
#    'catid': 76,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'dm',
#    'price_min': 25000000,
#    'liked_count': 11,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 7,
#    'status': 1,
#    'price_max': 25000000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 25000000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [5, 0, 0, 0, 0, 5],
#     'rcount_with_image': 0,
#     'rcount_with_context': 0},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '現貨＋預購 德國DM ebelin 氣墊長柄梳',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1527614245,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 11,
#    'transparent_background_image': ''},
#   {'itemid': 1203920956,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': '5430f19ffb191aed68170bdcf9a4be13',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['5430f19ffb191aed68170bdcf9a4be13',
#     'a6ed0eafcf66729d2ea71e40e068bd87',
#     'cec0a47f67e382c055157eff64679afc',
#     'bb2974ad73547e9edccdbfe0fd4ee741',
#     'e59710eb1368a4e08a33d9f5020f895f'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 5,
#    'view_count': 9,
#    'display_name': None,
#    'catid': 76,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'dm',
#    'price_min': 39000000,
#    'liked_count': 14,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 3,
#    'status': 1,
#    'price_max': 39000000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 39000000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [5, 0, 0, 0, 0, 5],
#     'rcount_with_image': 0,
#     'rcount_with_context': 3},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': [],
#      'properties': [],
#      'type': 0,
#      'name': '',
#      'options': ['']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '現貨＋預購 德國代購ebelin 抗毛躁梳子',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1527610525,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 7,
#    'transparent_background_image': ''},
#   {'itemid': 2729887368,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': '7c8ead41c885efb2a362ac0f7b5ad7a7',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['7c8ead41c885efb2a362ac0f7b5ad7a7',
#     '10a8b9216ef53c35da151e339bb80494',
#     'aa9f85e2a5127952abe707d37bea42a1'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 4,
#    'view_count': 0,
#    'display_name': None,
#    'catid': 100,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'invisibobble',
#    'price_min': 7500000,
#    'liked_count': 7,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 34,
#    'status': 1,
#    'price_max': 20900000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 7500000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [4, 0, 0, 0, 0, 4],
#     'rcount_with_image': 2,
#     'rcount_with_context': 2},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': [],
#      'properties': [],
#      'type': 0,
#      'name': '經典兒童',
#      'options': ['彩虹3入', '皇冠3入', '彩虹單條', '皇冠單條']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '💯現貨供應 💯德國 Invisibobble 神奇魔髮圈 寵愛寶寶款',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1567081148,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 7,
#    'transparent_background_image': ''},
#   {'itemid': 1249809332,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': 'bf4412251ff7af7686513e94a625d34a',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['bf4412251ff7af7686513e94a625d34a'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 3,
#    'view_count': 0,
#    'display_name': None,
#    'catid': 76,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': None,
#    'price_min': 36000000,
#    'liked_count': 7,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 4,
#    'status': 1,
#    'price_max': 36000000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 36000000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [3, 0, 0, 0, 0, 3],
#     'rcount_with_image': 0,
#     'rcount_with_context': 1},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': [],
#      'properties': [],
#      'type': 0,
#      'name': '',
#      'options': ['']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '現貨+預購 DM BALEA 海藻保濕臉部精華液30ML',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1529257597,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 6,
#    'transparent_background_image': ''},
#   {'itemid': 1203868739,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': '6626f57e5058f880c790445a89f6fe4f',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['6626f57e5058f880c790445a89f6fe4f'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 3,
#    'view_count': 0,
#    'display_name': None,
#    'catid': 76,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'DM Balea',
#    'price_min': 14000000,
#    'liked_count': 4,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 10,
#    'status': 1,
#    'price_max': 14000000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 14000000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [3, 0, 0, 0, 0, 3],
#     'rcount_with_image': 0,
#     'rcount_with_context': 2},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': [],
#      'properties': [],
#      'type': 0,
#      'name': '迷你梳',
#      'options': ['不挑款']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '現貨＋預購 德國代購 elebin 迷你梳（附鏡子）',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1527609200,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 4,
#    'transparent_background_image': ''},
#   {'itemid': 1203423044,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': '64b874143633c4ea31df59a1422296d0',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['64b874143633c4ea31df59a1422296d0'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 3,
#    'view_count': 1,
#    'display_name': None,
#    'catid': 76,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'dm',
#    'price_min': 25000000,
#    'liked_count': 11,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 10,
#    'status': 1,
#    'price_max': 25000000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 25000000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [3, 0, 0, 0, 0, 3],
#     'rcount_with_image': 0,
#     'rcount_with_context': 1},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': [],
#      'properties': [],
#      'type': 0,
#      'name': '',
#      'options': ['']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '現貨＋預購德國Balea 眼部滾珠 15ml',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1527600721,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 6,
#    'transparent_background_image': ''},
#   {'itemid': 1202860236,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': 'f7ff2dee72650708146e9ccb0862f760',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['f7ff2dee72650708146e9ccb0862f760',
#     '9d8a9b482503f0ef297a46fb4f0cbbdc'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 3,
#    'view_count': 0,
#    'display_name': None,
#    'catid': 67,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'dm',
#    'price_min': 37000000,
#    'liked_count': 10,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 4,
#    'status': 1,
#    'price_max': 37000000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 37000000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [3, 0, 0, 0, 0, 3],
#     'rcount_with_image': 0,
#     'rcount_with_context': 0},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': [],
#      'properties': [],
#      'type': 0,
#      'name': '選項',
#      'options': ['Balea 堅果深層修護髮膜300ml']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '現貨 德國Balea專業護髮膜（密集修護）',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1527590099,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 10,
#    'transparent_background_image': ''},
#   {'itemid': 2674931301,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': '3f66b585bca46be85a95b2a0ceb33645',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['3f66b585bca46be85a95b2a0ceb33645',
#     'f94a5e25f0a69ec4437690fdbbe7081f'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 4,
#    'view_count': 0,
#    'display_name': None,
#    'catid': 67,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'Balea 芭樂雅',
#    'price_min': 6900000,
#    'liked_count': 5,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 2,
#    'status': 1,
#    'price_max': 6900000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 6900000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 4.25,
#     'rating_count': [4, 0, 1, 0, 0, 3],
#     'rcount_with_image': 1,
#     'rcount_with_context': 2},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': ['3f66b585bca46be85a95b2a0ceb33645',
#       'f94a5e25f0a69ec4437690fdbbe7081f'],
#      'properties': [],
#      'type': 0,
#      'name': '護脣膏4.8G',
#      'options': ['夏日西瓜', '魅力可可椰子']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '現貨🥰 BALEA潤唇膏4.8G',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1566108971,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 7,
#    'transparent_background_image': ''},
#   {'itemid': 1203375750,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': '408a54622556884fd1581428319c0b35',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['408a54622556884fd1581428319c0b35',
#     '3b42b331879a8b0efe23ed4402f7b3e1'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 2,
#    'view_count': 15,
#    'display_name': None,
#    'catid': 76,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'dm',
#    'price_min': 32000000,
#    'liked_count': 15,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 1,
#    'status': 1,
#    'price_max': 32000000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 32000000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [2, 0, 0, 0, 0, 2],
#     'rcount_with_image': 1,
#     'rcount_with_context': 1},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': [],
#      'properties': [],
#      'type': 0,
#      'name': '',
#      'options': ['']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '現貨＋預購德國Balea完美睫毛增長精華液/4.5ml',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1527599886,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 3,
#    'transparent_background_image': ''},
#   {'itemid': 1294060592,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': '99a81022bc219ee8cadc74d155570713',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['99a81022bc219ee8cadc74d155570713',
#     '55c9c59ab47cb7d6d8ef49810c25741e'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 2,
#    'view_count': 26,
#    'display_name': None,
#    'catid': 67,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'BALEA VlTAL',
#    'price_min': 24000000,
#    'liked_count': 2,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 1,
#    'deduction_info': None,
#    'stock': 1,
#    'status': 1,
#    'price_max': 24000000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 24000000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [2, 0, 0, 0, 0, 2],
#     'rcount_with_image': 1,
#     'rcount_with_context': 2},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': [],
#      'properties': [],
#      'type': 0,
#      'name': '顏色',
#      'options': ['日晚霜']},
#     {'images': [],
#      'properties': [],
#      'type': 0,
#      'name': '尺寸',
#      'options': ['晚霜2020/04', '日霜2021/03']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '現貨出清👈數量有限售完不補✨✨BALEA VITAL+PLUS精油熟齡深層撫紋晚霜50ML',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1530750408,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 5,
#    'transparent_background_image': ''},
#   {'itemid': 1203528959,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': 'c86e3062733d39a954f66caebd07ccd3',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['c86e3062733d39a954f66caebd07ccd3',
#     'bb4bdf413463486ec3cd53ce1dc44773',
#     '33867a678c13180a1e9a5470d02a09da'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 2,
#    'view_count': 13,
#    'display_name': None,
#    'catid': 67,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'BALEA VlTAL',
#    'price_min': 22000000,
#    'liked_count': 7,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 1,
#    'deduction_info': None,
#    'stock': 4,
#    'status': 1,
#    'price_max': 22000000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 22000000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [2, 0, 0, 0, 0, 2],
#     'rcount_with_image': 1,
#     'rcount_with_context': 2},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': [],
#      'properties': [],
#      'type': 0,
#      'name': '選項',
#      'options': ['日霜2021/02', '晚霜2020/07', '晚霜2020/09']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
# ...
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': 'e3d29fed79dbf2d2fd968e1086390d9e',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['e3d29fed79dbf2d2fd968e1086390d9e'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 1,
#    'view_count': 0,
#    'display_name': None,
#    'catid': 76,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': None,
#    'price_min': 28500000,
#    'liked_count': 1,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 9,
#    'status': 1,
#    'price_max': 28500000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 28500000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [1, 0, 0, 0, 0, 1],
#     'rcount_with_image': 0,
#     'rcount_with_context': 0},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': [],
#      'properties': [],
#      'type': 0,
#      'name': '',
#      'options': ['']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '現貨+預購 德國 S-quitofree草本防蚊 驅蚊噴霧 100ml',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1528823344,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 1,
#    'transparent_background_image': ''},
#   {'itemid': 1227485452,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': '9a2caf4de34f0c6487defe26693cc886',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['9a2caf4de34f0c6487defe26693cc886',
#     '7d00597fc3c474968fc91573773cfe68',
#     '430897846c312260a3d98dab6e22dac0'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 1,
#    'view_count': 0,
#    'display_name': None,
#    'catid': 76,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': None,
#    'price_min': 25000000,
#    'liked_count': 5,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 29,
#    'status': 1,
#    'price_max': 25000000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 25000000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [1, 0, 0, 0, 0, 1],
#     'rcount_with_image': 0,
#     'rcount_with_context': 0},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': [],
#      'properties': [],
#      'type': 0,
#      'name': 'Variation',
#      'options': ['尿素', '蓮花萃取', 'Q10']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '現貨＋預購 德國Balea 尿素/ 蓮花萃取 / Q10 15ml眼霜',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1528309030,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 1,
#    'transparent_background_image': ''},
#   {'itemid': 1220243351,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': '7c71b62f87cf91a63ab1375e57af514c',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['7c71b62f87cf91a63ab1375e57af514c'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 1,
#    'view_count': 1,
#    'display_name': None,
#    'catid': 76,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'dm',
#    'price_min': 8900000,
#    'liked_count': 1,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 4,
#    'status': 1,
#    'price_max': 8900000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 8900000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 5.0,
#     'rating_count': [1, 0, 0, 0, 0, 1],
#     'rcount_with_image': 0,
#     'rcount_with_context': 0},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '激推!!!!!!!!!!Balea SOS 1分鐘速效髮膜20ml(現貨+預購)',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1528097806,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 1,
#    'transparent_background_image': ''},
#   {'itemid': 1377076377,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': 'd2e82285609316990563a0ae6b2f1674',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['d2e82285609316990563a0ae6b2f1674',
#     '8956a63a1fe00f9913d15a5744c83b8f'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 0,
#    'view_count': 1,
#    'display_name': None,
#    'catid': 76,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': None,
#    'price_min': 10000000,
#    'liked_count': 3,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 195,
#    'status': 1,
#    'price_max': 10000000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 10000000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 0.0,
#     'rating_count': [0, 0, 0, 0, 0, 0],
#     'rcount_with_image': 0,
#     'rcount_with_context': 0},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '現貨+預購 德國 Dontodent 0~6歲/6歲以上 補鈣護齒兒童牙膏100ML',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1533142874,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 5,
#    'transparent_background_image': ''},
#   {'itemid': 1321588636,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': 'd2a540650bdf04911d7d0eea30331872',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['d2a540650bdf04911d7d0eea30331872',
#     '62b9d71b1b874887733c6305bd329736'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 0,
#    'view_count': 1,
#    'display_name': None,
#    'catid': 76,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'domol',
#    'price_min': 28000000,
#    'liked_count': 4,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 199,
#    'status': 1,
#    'price_max': 28000000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 28000000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 0.0,
#     'rating_count': [0, 0, 0, 0, 0, 0],
#     'rcount_with_image': 0,
#     'rcount_with_context': 0},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '現貨＋預購 德國 domol 馬桶強效去污去味亮白錠 無香15/花香13入',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1531554172,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 1,
#    'transparent_background_image': ''},
#   {'itemid': 1249779956,
#    'welcome_package_info': None,
#    'liked': None,
#    'recommendation_info': None,
#    'bundle_deal_info': None,
#    'price_max_before_discount': -1,
#    'tracking_info': {'multi_search_tracking': [0],
#     'viral_spu_tracking': None,
#     'business_tracking': None},
#    'image': '34ac7f259e8ca63555b8d4cec4bf0a22',
#    'recommendation_algorithm': None,
#    'is_cc_installment_payment_eligible': False,
#    'shopid': 1819984,
#    'can_use_wholesale': False,
#    'group_buy_info': None,
#    'reference_item_id': '',
#    'currency': 'TWD',
#    'raw_discount': 0,
#    'show_free_shipping': False,
#    'video_info_list': [],
#    'ads_keyword': None,
#    'collection_id': None,
#    'images': ['34ac7f259e8ca63555b8d4cec4bf0a22'],
#    'is_preferred_plus_seller': False,
#    'price_before_discount': 0,
#    'is_category_failed': False,
#    'show_discount': 0,
#    'cmt_count': 0,
#    'view_count': 1,
#    'display_name': None,
#    'catid': 76,
#    'voucher_info': None,
#    'upcoming_flash_sale': None,
#    'is_official_shop': False,
#    'brand': 'dm',
#    'price_min': 35000000,
#    'liked_count': 1,
#    'can_use_bundle_deal': False,
#    'show_official_shop_label': False,
#    'coin_earn_label': None,
#    'price_min_before_discount': -1,
#    'cb_option': 0,
#    'sold': 0,
#    'deduction_info': None,
#    'stock': 99,
#    'status': 1,
#    'price_max': 35000000,
#    'add_on_deal_info': None,
#    'is_group_buy_item': None,
#    'flash_sale': None,
#    'price': 35000000,
#    'shop_location': '台中市潭子區',
#    'item_rating': {'rating_star': 0.0,
#     'rating_count': [0, 0, 0, 0, 0, 0],
#     'rcount_with_image': 0,
#     'rcount_with_context': 0},
#    'show_official_shop_label_in_title': False,
#    'tier_variations': [{'images': [],
#      'properties': [],
#      'type': 0,
#      'name': '',
#      'options': ['']}],
#    'is_adult': False,
#    'discount': None,
#    'flag': 65536,
#    'is_non_cc_installment_payment_eligible': False,
#    'has_lowest_price_guarantee': False,
#    'json_data': '',
#    'has_group_buy_stock': None,
#    'match_type': None,
#    'preview_info': None,
#    'welcome_package_type': 0,
#    'exclusive_price_info': None,
#    'name': '現貨+預購 德國 Denkmit 馬桶清潔發泡錠16入',
#    'distance': None,
#    'adsid': None,
#    'ctime': 1529255535,
#    'wholesale_tier_list': [],
#    'show_shopee_verified_label': False,
#    'campaignid': None,
#    'show_official_shop_label_in_normal_position': None,
#    'item_status': 'normal',
#    'shopee_verified': False,
#    'hidden_price_display': None,
#    'size_chart': None,
#    'item_type': 0,
#    'shipping_icon_type': None,
#    'campaign_stock': None,
#    'label_ids': [],
#    'service_by_shopee_flag': None,
#    'badge_icon_type': 0,
#    'historical_sold': 1,
#    'transparent_background_image': ''}],
#  'reserved_keyword': '',
#  'hint_keywords': []}

# %% [markdown]
# #### 參考資料
# https://blog.furas.pl/python-scaping-how-to-scrape-shopee.tw.html
