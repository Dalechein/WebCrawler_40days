# %% [markdown]
# # 動態網頁爬蟲 - API Request
#
# * 了解 API Request 用於動態網頁爬蟲的原理
# * 能夠使用 API Request 撰寫動態網頁爬蟲

# %% [markdown]
# ## 作業目標
#
# * 根據範例的教學，去找出 Dcard 中呼叫的 API 當中，有一個跟「取得所有看板」是哪一個？並且利用 Requests 呼叫。

# %% [markdown]
# * 請附上截圖：_______
#
# ![]()

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import requests
import time
import json

# %%
# 1. 請試著利用 Selenium 開啟 Google 網頁，不要關掉。
browser = webdriver.Chrome(executable_path='chromedriver')
browser.get("https://www.dcard.tw/_api/forums/dressup/posts")
# browser.get("https://www.dcard.tw/_api/forums")
# browser.get("https://www.dcard.tw/service/api/forums")
# https://www.dcard.tw/service/api/v2/forums/pet/posts

#www.dcard.tw/_api/
time.sleep(10)

# 取得資料（等瀏覽器資料出現後才執行）
html_source = browser.page_source
html = BeautifulSoup(html_source, 'lxml')
html
# Out:
# <html><head></head><body><pre style="word-wrap: break-word; white-space: pre-wrap;">[{"id":235361775,"title":"關於粉紅長夾","excerpt":"想詢問有男性的長夾式選擇粉紅色的嗎？那對於粉色長夾的看法是什麼？圖片擷取至網路，我自己是蠻喜歡粉紅色的，所以想問問大家的看法","anonymousSchool":false,"anonymousDepartment":false,"pinned":false,"forumId":"be1a095b-175e-4523-9e06-66a05d939676","replyId":null,"createdAt":"2021-02-16T11:03:54.752Z","updatedAt":"2021-02-16T11:09:16.677Z","commentCount":0,"likeCount":0,"withNickname":true,"tags":[],"topics":["穿搭","男生穿搭","日常穿搭","包包","選色"],"meta":{"layout":"classic"},"forumName":"穿搭","forumAlias":"dressup","nsfw":false,"gender":"M","school":"琺","department":"xiutingli","replyTitle":null,"reportReason":"","mediaMeta":[{"id":"fe5dac22-e151-4748-b384-4fbe3cbcbae9","url":"https://i.imgur.com/0ZkQnm2l.jpg","normalizedUrl":"https://i.imgur.com/0ZkQnm2l.jpg","thumbnail":"https://i.imgur.com/0ZkQnm2l.jpg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2021-02-16T11:03:54.752Z","updatedAt":"2021-02-16T11:09:16.677Z","width
# ...

# %%
data = json.loads(html.text)
data[:10]
# Out:
# [{'id': 235361775,
#   'title': '關於粉紅長夾',
#   'excerpt': '想詢問有男性的長夾式選擇粉紅色的嗎？那對於粉色長夾的看法是什麼？圖片擷取至網路，我自己是蠻喜歡粉紅色的，所以想問問大家的看法',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': 'be1a095b-175e-4523-9e06-66a05d939676',
#   'replyId': None,
#   'createdAt': '2021-02-16T11:03:54.752Z',
#   'updatedAt': '2021-02-16T11:09:16.677Z',
#   'commentCount': 0,
#   'likeCount': 0,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['穿搭', '男生穿搭', '日常穿搭', '包包', '選色'],
#   'meta': {'layout': 'classic'},
#   'forumName': '穿搭',
#   'forumAlias': 'dressup',
#   'nsfw': False,
#   'gender': 'M',
#   'school': '琺',
#   'department': 'xiutingli',
#   'replyTitle': None,
#   'reportReason': '',
#   'mediaMeta': [{'id': 'fe5dac22-e151-4748-b384-4fbe3cbcbae9',
#     'url': 'https://i.imgur.com/0ZkQnm2l.jpg',
#     'normalizedUrl': 'https://i.imgur.com/0ZkQnm2l.jpg',
#     'thumbnail': 'https://i.imgur.com/0ZkQnm2l.jpg',
#     'type': 'image/thumbnail',
# ...

# %%
#API            URL
#看板資訊(meta)  http://dcard.tw/_api/forums
#文章資訊(meta)  http://dcard.tw/_api/forums/{看板名稱}/posts
#文章內文        http://dcard.tw/_api/posts/{文章編號}
#文章內引用連結  http://dcard.tw/_api/posts/{文章編號}/links
#文章內留言      http://dcard.tw/_api/posts/{文章編號}/comments
